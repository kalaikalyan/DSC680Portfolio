# %%
#Load necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Function to read a csv file is read_csv
df = pd.read_csv("sales_record.csv")
df
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0           Online              M  12/20/2013  957081544   1/11/2014
# 1          Offline              C    7/5/2010  301644504   7/26/2010
# 2          Offline              C   9/12/2011  478051030   9/29/2011
# 3          Offline              L   5/13/2010  892599952   6/15/2010
# 4          Offline              C   7/20/2015  571902596   7/27/2015
# ...            ...            ...         ...        ...         ...
# 4995       Offline              C    4/3/2015  217984473   4/20/2015
# 4996       Offline              L   8/17/2014  169748055   10/2/2014
# 4997       Offline              H  11/23/2016  226939189  12/10/2016
# 4998        Online              L   4/22/2014  906794202   5/11/2014
# 4999        Online              L    7/8/2011  996861922    8/7/2011
#
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0            552      255.28     159.42      140914.56    87999.84
# 1           2167      152.58      97.44      330640.86   211152.48
# 2           4778       47.45      31.79      226716.10   151892.62
# 3           9016      205.70     117.11     1854591.20  1055863.76
# 4           7542      152.58      97.44     1150758.36   734892.48
# ...          ...         ...        ...            ...         ...
# 4995        5305      668.27     502.54     3545172.35  2665974.70
# 4996        1077      109.28      35.84      117694.56    38599.68
# 4997        5204      255.28     159.42     1328477.12   829621.68
# 4998        9410      109.28      35.84     1028324.80   337254.40
# 4999        2450      154.06      90.93      377447.00   222778.50
#
#       Total Profit
# 0         52914.72
# 1        119488.38
# 2         74823.48
# 3        798727.44
# 4        415865.88
# ...            ...
# 4995     879197.65
# 4996      79094.88
# 4997     498855.44
# 4998     691070.40
# 4999     154668.50
#
# [5000 rows x 14 columns]

# %%
df_subset = df[[ 'Region', 'Unit Price','Total Profit','Item Type']]
df_subset.head()
# Out:
#                               Region  Unit Price  Total Profit  Item Type
# 0  Central America and the Caribbean      255.28      52914.72  Baby Food
# 1  Central America and the Caribbean      152.58     119488.38     Snacks
# 2                             Europe       47.45      74823.48  Beverages
# 3                               Asia      205.70     798727.44     Cereal
# 4                               Asia      152.58     415865.88     Snacks

# %%
df1 = df_subset.groupby('Region').describe()['Total Profit']
df1
# Out:
#                                     count           mean            std  \
# Region
# Asia                                719.0  386978.667163  384988.998809
# Australia and Oceania               416.0  420515.800337  393038.644587
# Central America and the Caribbean   534.0  383168.501348  366185.113560
# Europe                             1330.0  377200.036331  368983.280427
# Middle East and North Africa        610.0  379311.968082  375112.739526
# North America                       106.0  389060.358208  424858.296808
# Sub-Saharan Africa                 1285.0  413340.286319  398686.037723
#
#                                        min          25%         50%  \
# Region
# Asia                                159.06   75413.6200  266657.040
# Australia and Oceania                62.64  119438.2750  320785.920
# Central America and the Caribbean   146.88   86869.3725  280613.545
# Europe                              130.14   84822.9375  273594.610
# Middle East and North Africa       1062.81   80954.3250  243985.520
# North America                        16.87   72183.2825  226699.070
# Sub-Saharan Africa                  146.88   85597.5600  313726.890
#
#                                            75%         max
# Region
# Asia                               568378.3000  1699926.99
# Australia and Oceania              594990.5250  1696275.72
# Central America and the Caribbean  545824.1675  1664283.64
# Europe                             547658.1750  1700448.60
# Middle East and North Africa       564777.4150  1710011.45
# North America                      561497.3450  1703404.39
# Sub-Saharan Africa                 609015.1100  1726007.49

# %%
#Scatter plot
plt.xlabel('Total Profit',fontsize = 25)
plt.ylabel('Item Type',fontsize = 25)
plt.scatter(df['Total Profit'],df['Item Type'])

# %%
#  bar chart


plt.bar( df['Item Type'],df['Total Profit'])
plt.title('Total Profit',fontsize = 20)
plt.ylabel('Total Profit',fontsize = 15)
plt.xlabel('Item Type',fontsize = 15)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='large'  
)
plt.grid(False)

plt.show()

# %%
#Line chart
plt.plot( df1['count'],df1['mean'])

plt.title('Total Profit',fontsize = 20)
plt.xlabel('count',fontsize = 15)
plt.ylabel('mean',fontsize = 15)
plt.grid(True)
plt.show()

# %%
#Histogram
plt.ylabel('Frequency')
plt.xlabel('Total Profit')
df["Item Type"],df['Total Profit'].hist(bins=20)
# Out:
# (0        Baby Food
#  1           Snacks
#  2        Beverages
#  3           Cereal
#  4           Snacks
#             ...
#  4995     Household
#  4996       Clothes
#  4997     Baby Food
#  4998       Clothes
#  4999    Vegetables
#  Name: Item Type, Length: 5000, dtype: object,
#  <AxesSubplot:xlabel='Total Profit', ylabel='Frequency'>)
